# %% [markdown]
# <a href="https://colab.research.google.com/github/rushinakhale115/NLP_Assignments/blob/main/NLP_Assignments/Ass_11_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 98.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
Artificial intelligence is transforming modern technology.
Machine learning algorithms analyze large amounts of data.
Deep neural networks are used in computer vision and natural language processing.
"""

# %%
doc = nlp(text)

# %%
noun_phrases = [chunk.text for chunk in doc.noun_chunks]

print("Noun Phrases:\n")
for np in noun_phrases:
    print(np)
# Out:
# Noun Phrases:
#
#
# Artificial intelligence
# modern technology
# Machine learning algorithms
# large amounts
# data
# Deep neural networks
# computer vision
# natural language processing

# %%
for token in doc:
    print(token.text, "->", token.pos_)
# Out:
#  -> SPACE
# Artificial -> ADJ
# intelligence -> NOUN
# is -> AUX
# transforming -> VERB
# modern -> ADJ
# technology -> NOUN
# . -> PUNCT
#
#  -> SPACE
# Machine -> NOUN
# learning -> VERB
# algorithms -> NOUN
# analyze -> VERB
# large -> ADJ
# amounts -> NOUN
# of -> ADP
# data -> NOUN
# . -> PUNCT
#
#  -> SPACE
# Deep -> PROPN
# neural -> NOUN
# networks -> NOUN
# are -> AUX
# used -> VERB
# in -> ADP
# computer -> NOUN
# vision -> NOUN
# and -> CCONJ
# natural -> ADJ
# language -> NOUN
# processing -> NOUN
# . -> PUNCT
#
#  -> SPACE
