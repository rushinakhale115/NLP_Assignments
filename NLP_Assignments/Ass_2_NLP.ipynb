# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
dataset = [
    "Natural language processing is fascinating.",
    "POS tagging assigns grammatical labels to words.",
    "Python is widely used for text analysis."
]

# %%
nltk.download('averaged_perceptron_tagger_eng')

print("PART-OF-SPEECH TAGGING:\n")

for sentence in dataset:
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    print(f"Sentence: {sentence}")
    print("POS Tags:")
    print(pos_tags)
    print()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# PART-OF-SPEECH TAGGING:
#
# Sentence: Natural language processing is fascinating.
# POS Tags:
# [('Natural', 'JJ'), ('language', 'NN'), ('processing', 'NN'), ('is', 'VBZ'), ('fascinating', 'VBG'), ('.', '.')]
#
# Sentence: POS tagging assigns grammatical labels to words.
# POS Tags:
# [('POS', 'NNP'), ('tagging', 'VBG'), ('assigns', 'RB'), ('grammatical', 'JJ'), ('labels', 'NNS'), ('to', 'TO'), ('words', 'NNS'), ('.', '.')]
#
# Sentence: Python is widely used for text analysis.
# POS Tags:
# [('Python', 'NNP'), ('is', 'VBZ'), ('widely', 'RB'), ('used', 'VBN'), ('for', 'IN'), ('text', 'JJ'), ('analysis', 'NN'), ('.', '.')]

# %%
for sentence in dataset:
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)
    print(sentence)
    for word, tag in pos_tags:
        print(f"{word:15} -> {tag}")
    print()
# Out:
# Natural language processing is fascinating.
# Natural         -> JJ
# language        -> NN
# processing      -> NN
# is              -> VBZ
# fascinating     -> VBG
# .               -> .
#
# POS tagging assigns grammatical labels to words.
# POS             -> NNP
# tagging         -> VBG
# assigns         -> RB
# grammatical     -> JJ
# labels          -> NNS
# to              -> TO
# words           -> NNS
# .               -> .
#
# Python is widely used for text analysis.
# Python          -> NNP
# is              -> VBZ
# widely          -> RB
# used            -> VBN
# for             -> IN
# text            -> JJ
# analysis        -> NN
# .               -> .
