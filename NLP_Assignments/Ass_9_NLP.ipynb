# %% [markdown]
# <a href="https://colab.research.google.com/github/rushinakhale115/NLP_Assignments/blob/main/NLP_Assignments/Ass_9_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Import Libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

print("Libraries imported!")
print("TensorFlow version:", tf.__version__)
# Out:
# Libraries imported!
# TensorFlow version: 2.19.0

# %%
text = """
the cat sat on the mat and the cat is fat
the dog ran in the park near the lake
the sun is bright and the sky is blue
birds sing songs in the morning light
children love to play in the park
the moon glows bright in the night sky
flowers bloom in spring and summer days
the river flows fast through the valley
""".lower().strip()

# Get all unique characters
chars    = sorted(set(text))
vocab_size = len(chars)

# Create mappings
char2idx = {c: i for i, c in enumerate(chars)}
idx2char = {i: c for c, i in char2idx.items()}

# Encode full text
encoded = [char2idx[c] for c in text]

print("Text ready!")
print("Vocabulary size :", vocab_size)
print("Unique chars    :", ''.join(chars))
print("Total characters:", len(text))
# Out:
# Text ready!
# Vocabulary size : 24
# Unique chars    :
#  abcdefghiklmnoprstuvwy
# Total characters: 308

# %%
seq_length = 15
X_data, y_data = [], []

for i in range(len(encoded) - seq_length):
    X_data.append(encoded[i : i + seq_length])
    y_data.append(encoded[i + seq_length])

X = np.array(X_data)
y = to_categorical(y_data, num_classes=vocab_size)

print("Sequences created!")
print("X shape:", X.shape)
print("y shape:", y.shape)
print("Sample input  :", ''.join([idx2char[i] for i in X[0]]))
print("Target char   :", idx2char[np.argmax(y[0])])
# Out:
# Sequences created!
# X shape: (293, 15)
# y shape: (293, 24)
# Sample input  : the cat sat on
# Target char   : t

# %%
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=seq_length),
    SimpleRNN(128, activation='tanh'),
    Dense(64, activation='relu'),
    Dense(vocab_size, activation='softmax')
])

model.build(input_shape=(None, seq_length))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
print("\nModel built successfully!")
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 15, 32)         │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 128)            │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 24)             │         1,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,192 (121.84 KB)
#  Trainable params: 31,192 (121.84 KB)
#  Non-trainable params: 0 (0.00 B)
# Model built successfully!

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='accuracy', patience=8,
                           restore_best_weights=True, verbose=1)

print("Training started...\n")

history = model.fit(
    X, y,
    epochs=120,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

acc = history.history['accuracy'][-1] * 100
print(f"\nTraining complete! Final Accuracy: {acc:.2f}%")
# Out:
# Training started...
#
# Epoch 1/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.0922 - loss: 3.1412
# Epoch 2/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1809 - loss: 2.9609
# Epoch 3/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1843 - loss: 2.8742
# Epoch 4/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1945 - loss: 2.7437
# Epoch 5/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2253 - loss: 2.6490
# Epoch 6/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2491 - loss: 2.5108
# Epoch 7/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3072 - loss: 2.4021
# Epoch 8/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3311 - loss: 2.2721
# Epoch 9/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3720 - loss: 2.2018
# Epoch 10/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3788 - loss: 2.0730
# Epoch 11/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4198 - loss: 1.9600
# Epoch 12/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4505 - loss: 1.8705
# Epoch 13/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4642 - loss: 1.8126
# Epoch 14/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5017 - loss: 1.6988
# Epoch 15/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5461 - loss: 1.5923
# Epoch 16/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5904 - loss: 1.4688
# Epoch 17/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6177 - loss: 1.4065
# Epoch 18/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6382 - loss: 1.3813
# Epoch 19/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6792 - loss: 1.2917
# Epoch 20/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6894 - loss: 1.2025
# Epoch 21/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7201 - loss: 1.1003
# Epoch 22/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7372 - loss: 1.0315
# Epoch 23/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7816 - loss: 0.9963
# Epoch 24/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8020 - loss: 0.8855
# Epoch 25/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8498 - loss: 0.7705
# Epoch 26/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8532 - loss: 0.7026
# Epoch 27/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8532 - loss: 0.6675
# Epoch 28/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8874 - loss: 0.6019
# Epoch 29/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9010 - loss: 0.5376
# Epoch 30/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8874 - loss: 0.5322
# Epoch 31/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9010 - loss: 0.4770
# Epoch 32/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9147 - loss: 0.4623
# Epoch 33/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9522 - loss: 0.4103
# Epoch 34/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9283 - loss: 0.3816
# Epoch 35/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9556 - loss: 0.3704
# Epoch 36/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9420 - loss: 0.3294
# Epoch 37/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9420 - loss: 0.3517
# Epoch 38/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9795 - loss: 0.2599
# Epoch 39/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9863 - loss: 0.2137
# Epoch 40/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9795 - loss: 0.1930
# Epoch 41/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1509
# Epoch 42/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1303
# Epoch 43/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1178
# Epoch 44/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.1071
# Epoch 45/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0966
# Epoch 46/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0930
# Epoch 47/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9966 - loss: 0.0944
# Epoch 48/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0813
# Epoch 49/120
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9966 - loss: 0.0799
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 41.
#
# Training complete! Final Accuracy: 99.66%

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['loss'], color='blue', label='Loss')
axes[0].set_title('Training Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True)

axes[1].plot(history.history['accuracy'], color='green', label='Accuracy')
axes[1].set_title('Training Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
print("Plots shown!")
# Out:
# Plots shown!

# %%
def generate_text(seed, num_chars=60):
    result = seed
    seq    = seed.lower()

    for _ in range(num_chars):
        # Encode seed
        enc = [char2idx.get(c, 0) for c in seq[-seq_length:]]

        # Pad if needed
        if len(enc) < seq_length:
            enc = [0] * (seq_length - len(enc)) + enc

        X_in = np.array([enc])
        pred = model.predict(X_in, verbose=0)[0]

        # Pick most likely next character
        next_idx  = np.argmax(pred)
        next_char = idx2char[next_idx]

        result += next_char
        seq    += next_char

    return result

print("Text generation function ready!")
# Out:
# Text generation function ready!

# %%
seeds = [
    "the cat sat",
    "the dog ran",
    "the sun is",
    "birds sing",
    "children love",
    "the moon glo",
    "flowers bloo",
    "the river fl",
    "the sky is b",
    "the mat and",
    "morning ligh",
    "spring and s",
    "the park nea",
    "the night sk",
    "the valley a"
]

print("=" * 68)
print("      RNN LANGUAGE MODEL — 15 TEXT GENERATION OUTPUTS")
print("=" * 68)

for i, seed in enumerate(seeds, 1):
    output = generate_text(seed, num_chars=45)
    print(f"\n {i:2}. Seed     : \"{seed}\"")
    print(f"     Generated : \"{output}\"")

print("\n" + "=" * 68)
print(f"  Model Final Accuracy : {history.history['accuracy'][-1]*100:.2f}%")
print(f"  Total Parameters     : {model.count_params():,}")
print(f"  Vocabulary Size      : {vocab_size} characters")
print(f"  Sequence Length      : {seq_length}")
print("=" * 68)
# Out:
# ====================================================================
#       RNN LANGUAGE MODEL — 15 TEXT GENERATION OUTPUTS
# ====================================================================
#
#   1. Seed     : "the cat sat"
#      Generated : "the cat satary
# the mat andalh  rat is bl
# th aarnsthe a y"
#
#   2. Seed     : "the dog ran"
#      Generated : "the dog ran is the park neal the lake
# the sun is bright "
#
#   3. Seed     : "the sun is"
#      Generated : "the sun is aiight and tre sry is blt t rkrs srng y alrb"
#
#   4. Seed     : "birds sing"
#      Generated : "birds singt ings in the msg ing light
# the sren lo en ho"
#
#   5. Seed     : "children love"
#      Generated : "children love to play in the park
# the moon glows bright in"
#
#   6. Seed     : "the moon glo"
#      Generated : "the moon glois bright in  the sky hs rise
# birds ton loong"
#
#   7. Seed     : "flowers bloo"
#      Generated : "flowers bloo lin spring  nn summer daysoe anriver
# thet s"
#
#   8. Seed     : "the river fl"
#      Generated : "the river fliis fast thron m the valle rat
# the sothe  an"
#
#   9. Seed     : "the sky is b"
#      Generated : "the sky is blig
# birds sing longs in the mk nin al
# ehbrris"
#
#  10. Seed     : "the mat and"
#      Generated : "the mat and lsg rat is bat  nr  ngsrng tss isg mnwea lln"
#
#  11. Seed     : "morning ligh"
#      Generated : "morning lighi liildree loh  ss plriai  t soo mkre t  ssn "
#
#  12. Seed     : "spring and s"
#      Generated : "spring and s mler daysf fan tler fheathe munhrlovo thr so"
#
#  13. Seed     : "the park nea"
#      Generated : "the park nealyghe lake
# the shn is bright toe the sky in t"
#
#  14. Seed     : "the night sk"
#      Generated : "the night skys lowers bloom in spring and summer days
# the"
#
#  15. Seed     : "the valley a"
#      Generated : "the valley ais the sa hr sar th  s oorg ea so sn lin the "
#
# ====================================================================
#   Model Final Accuracy : 99.66%
#   Total Parameters     : 31,192
#   Vocabulary Size      : 24 characters
#   Sequence Length      : 15
# ====================================================================
